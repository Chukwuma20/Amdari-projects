# %%
import numpy as np
import pandas as pd
from pathlib import Path #this imports the tool for managing file paths/locations

# %%
from process_specification import dataset_specs #import the dicitionary and dicitonary variable(dataset_specs) from the process_specification.py file

# %%
data_folder = "csv.files"

def extract(dataset_specs, data_folder):  #Create a function called extract. 
    file_path = Path(data_folder) / dataset_specs["file_name"]  #Create a variable called file_path that combines the data_folder and the file_name from the dataset_specs dictionary.                                      

    df = pd.read_csv(                   #  Read the CSV into a DataFrame.
        file_path,
        dtype=str,
        keep_default_na=False 
    )

    mapping = dataset_specs["column_mapping"]

#when you read a csv into pandas (e.g pd.read_csv ("file.csv")), the column headers on your csv file becomes df.columns.
    actual_columns = set(df.columns)  #Create a variable called actual_columns that contains the set of column names in the DataFrame.

    expected_columns = set(mapping.keys())
    missing_columns = expected_columns - actual_columns

# The specification tells us what columns we expect. We compare those against the CSV. If anything is missing, we stop immediately because the input data doesn't meet our contract.
# That's basically what "fail fast" and "broken batch contract" mean in this task. so this is the fail fast part
    if missing_columns:
          raise ValueError(
            f"Missing expected columns in {dataset_specs['file_name']}: "
            f"{sorted(missing_columns)}"  #sort the results of the missing_columns in alphabetical order 
        )

    df = df[list(mapping.keys())]  #Selects only the columns defined in the specification. df[] filters the DataFrame to include only the columns specified in the mapping dictionary. list(mapping.keys())/ list(mapping) creates a list of the expected column names based on the keys of the mapping dictionary.
    df = df.rename(columns=mapping)
   
    return df

# %%
encounters_df = extract(dataset_specs["encounters"], data_folder) #call the extract function and pass the encounters dataset specification and the data folder path. The result is stored in encounters_df.
print(encounters_df.columns.tolist())
encounters_df.head()
# Out:
# ['ENCOUNTER_ID', 'START_TIMESTAMP', 'STOP_TIMESTAMP', 'PATIENT_ID', 'ORGANIZATION_ID', 'PROVIDER_ID', 'PAYER_ID', 'ENCOUNTER_CLASS', 'ENCOUNTER_CODE', 'ENCOUNTER_DESCRIPTION', 'TOTAL_CLAIM_COST', 'PAYER_COVERAGE']
#                            ENCOUNTER_ID       START_TIMESTAMP  \
# 0  fe621c76-a591-b7be-bd84-05fbbefb22b4  2016-01-30T22:47:14Z
# 1  fe621c76-a591-b7be-ac26-b3481f6a2205  2016-12-17T13:47:14Z
# 2  fe621c76-a591-b7be-e5a3-71cf8c4a3131  2016-12-23T22:47:14Z
# 3  fe621c76-a591-b7be-d670-a0718ed4a47a  2017-02-04T22:47:14Z
# 4  fe621c76-a591-b7be-ef1b-1ed26b1b01a5  2017-02-18T22:47:14Z
#
#          STOP_TIMESTAMP                            PATIENT_ID  \
# 0  2016-01-30T23:02:14Z  fe621c76-a591-b7be-5668-b77f00240d82
# 1  2016-12-17T14:02:14Z  fe621c76-a591-b7be-5668-b77f00240d82
# 2  2016-12-23T23:02:14Z  fe621c76-a591-b7be-5668-b77f00240d82
# 3  2017-02-04T23:12:06Z  fe621c76-a591-b7be-5668-b77f00240d82
# 4  2017-02-19T02:24:54Z  fe621c76-a591-b7be-5668-b77f00240d82
#
#                         ORGANIZATION_ID                           PROVIDER_ID  \
# 0  39c15c0f-5c49-311e-99d2-1fb99d80e06e  4017bd91-3e46-3ba5-a9ec-58fddb0a8778
# 1  6cf8a214-8d57-3267-85e5-7719e15cd63e  29e69e63-32ee-385c-a255-b20e0e70755c
# 2  6cf8a214-8d57-3267-85e5-7719e15cd63e  29e69e63-32ee-385c-a255-b20e0e70755c
# 3  39c15c0f-5c49-311e-99d2-1fb99d80e06e  4017bd91-3e46-3ba5-a9ec-58fddb0a8778
# 4  6cf8a214-8d57-3267-85e5-7719e15cd63e  29e69e63-32ee-385c-a255-b20e0e70755c
#
#                                PAYER_ID ENCOUNTER_CLASS ENCOUNTER_CODE  \
# 0  df166300-5a78-3502-a46a-832842197811        wellness      410620009
# 1  df166300-5a78-3502-a46a-832842197811      ambulatory      185345009
# 2  df166300-5a78-3502-a46a-832842197811      outpatient      698314001
# 3  df166300-5a78-3502-a46a-832842197811        wellness      410620009
# 4  df166300-5a78-3502-a46a-832842197811      ambulatory      185349003
#
#                     ENCOUNTER_DESCRIPTION TOTAL_CLAIM_COST PAYER_COVERAGE
# 0            Well child visit (procedure)           919.90         819.90
# 1       Encounter for symptom (procedure)           775.79         725.79
# 2  Consultation for treatment (procedure)           142.58          92.58
# 3            Well child visit (procedure)           704.20         604.20
# 4      Encounter for check up (procedure)          3536.75        3486.75

# %%
encounters_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7210 entries, 0 to 7209
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ENCOUNTER_ID           7210 non-null   str
#  1   START_TIMESTAMP        7210 non-null   str
#  2   STOP_TIMESTAMP         7210 non-null   str
#  3   PATIENT_ID             7210 non-null   str
#  4   ORGANIZATION_ID        7210 non-null   str
#  5   PROVIDER_ID            7210 non-null   str
#  6   PAYER_ID               7210 non-null   str
#  7   ENCOUNTER_CLASS        7210 non-null   str
#  8   ENCOUNTER_CODE         7210 non-null   str
#  9   ENCOUNTER_DESCRIPTION  7210 non-null   str
#  10  TOTAL_CLAIM_COST       7210 non-null   str
#  11  PAYER_COVERAGE         7210 non-null   str
# dtypes: str(12)
# memory usage: 676.1 KB
