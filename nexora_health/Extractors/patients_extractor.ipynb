# %%
import numpy as np
import pandas as pd
from pathlib import Path #this imports the tool for managing file paths/locations

# %%
from process_specification import dataset_specs #import the dicitionary and dicitonary variable(dataset_specs) from the process_specification.py file

# %%
data_folder = "csv.files"

def extract(dataset_specs, data_folder):  #Create a function called extract. 
    file_path = Path(data_folder) / dataset_specs["file_name"]  #Create a variable called file_path that combines the data_folder and the file_name from the dataset_specs dictionary.                                      

    df = pd.read_csv(                   #  Read the CSV into a DataFrame.
        file_path,
        dtype=str,
        keep_default_na=False 
    )

    mapping = dataset_specs["column_mapping"]

#when you read a csv into pandas (e.g pd.read_csv ("file.csv")), the column headers on your csv file becomes df.columns.
    actual_columns = set(df.columns)  #Create a variable called actual_columns that contains the set of column names in the DataFrame.

    expected_columns = set(mapping.keys())
    missing_columns = expected_columns - actual_columns

# The specification tells us what columns we expect. We compare those against the CSV. If anything is missing, we stop immediately because the input data doesn't meet our contract.
# That's basically what "fail fast" and "broken batch contract" mean in this task. so this is the fail fast part
    if missing_columns:
          raise ValueError(
            f"Missing expected columns in {dataset_specs['file_name']}: "
            f"{sorted(missing_columns)}"  #sort the results of the missing_columns in alphabetical order 
        )

    df = df[list(mapping.keys())]  #Selects only the columns defined in the specification. df[] filters the DataFrame to include only the columns specified in the mapping dictionary. list(mapping.keys())/ list(mapping) creates a list of the expected column names based on the keys of the mapping dictionary.
    df = df.rename(columns=mapping)
   
    return df

# %%
patients_df = extract(dataset_specs["patients"], data_folder) #call the extract function and pass the patients dataset specification and the data folder path. The result is stored in patients_df.
print(patients_df.columns.tolist())
patients_df.head()
# Out:
# ['PATIENT_ID', 'BIRTH_DATE', 'DEATH_DATE', 'GENDER', 'RACE', 'ETHNICITY', 'CITY', 'STATE', 'COUNTY', 'ZIP', 'LATITUDE', 'LONGITUDE', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'INCOME']
#                              PATIENT_ID  BIRTH_DATE DEATH_DATE GENDER   RACE  \
# 0  fe621c76-a591-b7be-5668-b77f00240d82  2001-12-29                 F  white
# 1  5f01f823-c8e8-9e40-c911-54b7b1ad843a  1969-07-11                 F  white
# 2  cba958fc-9355-f095-bf77-d56a20511339  1997-03-28                 M  white
# 3  1f0dab59-2cb5-5b52-9687-536444ee049b  1973-11-15                 F  white
# 4  a7796e87-b978-ed56-31f8-c93095b90340  1999-11-19                 M  asian
#
#      ETHNICITY      CITY          STATE            COUNTY    ZIP  \
# 0  nonhispanic    Boston  Massachusetts    Suffolk County  02118
# 1  nonhispanic    Milton  Massachusetts    Norfolk County  02186
# 2  nonhispanic  Franklin  Massachusetts    Norfolk County  02038
# 3     hispanic   Danvers  Massachusetts      Essex County  01923
# 4  nonhispanic   Sudbury  Massachusetts  Middlesex County  00000
#
#              LATITUDE           LONGITUDE HEALTHCARE_EXPENSES  \
# 0  42.292642702229884  -71.06291182663924             5891.27
# 1  42.272782654635925  -71.04375682836913           189706.47
# 2   42.12964440321107  -71.43306576980645            49809.31
# 3   42.61073411447473  -71.00800968453157            42810.01
# 4  42.374509049473424  -71.47081516347507            54566.70
#
#   HEALTHCARE_COVERAGE  INCOME
# 0           298460.31   11272
# 1           685859.80  179290
# 2             2049.70   55723
# 3          1317375.19  188501
# 4            33506.70   77367

# %%
patients_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 patients_df.info()
#
# NameError: name 'patients_df' is not defined
